# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(r"/content/drive/MyDrive/Bitcoin_Data.csv")

# %%
styled_df = df.head(6).style.set_table_styles(
    [{'selector': 'thead', 'props': [('background-color', 'black'), ('color', 'white'), ('font-weight', 'bold')]},
     {'selector': 'tbody tr:nth-child(even)', 'props': [('background-color', 'lightgray')]},
     {'selector': 'tbody tr:nth-child(odd)', 'props': [('background-color', 'white')]}]
).set_properties(**{'text-align': 'center', 'border': '1px solid black'})

styled_df
# Out:
# <style type="text/css">
# #T_569d9 thead {
#   background-color: black;
#   color: white;
#   font-weight: bold;
# }
# #T_569d9 tbody tr:nth-child(even) {
#   background-color: lightgray;
# }
# #T_569d9 tbody tr:nth-child(odd) {
#   background-color: white;
# }
# #T_569d9_row0_col0, #T_569d9_row0_col1, #T_569d9_row0_col2, #T_569d9_row0_col3, #T_569d9_row0_col4, #T_569d9_row0_col5, #T_569d9_row0_col6, #T_569d9_row0_col7, #T_569d9_row1_col0, #T_569d9_row1_col1, #T_569d9_row1_col2, #T_569d9_row1_col3, #T_569d9_row1_col4, #T_569d9_row1_col5, #T_569d9_row1_col6, #T_569d9_row1_col7, #T_569d9_row2_col0, #T_569d9_row2_col1, #T_569d9_row2_col2, #T_569d9_row2_col3, #T_569d9_row2_col4, #T_569d9_row2_col5, #T_569d9_row2_col6, #T_569d9_row2_col7, #T_569d9_row3_col0, #T_569d9_row3_col1, #T_569d9_row3_col2, #T_569d9_row3_col3, #T_569d9_row3_col4, #T_569d9_row3_col5, #T_569d9_row3_col6, #T_569d9_row3_col7, #T_569d9_row4_col0, #T_569d9_row4_col1, #T_569d9_row4_col2, #T_569d9_row4_col3, #T_569d9_row4_col4, #T_569d9_row4_col5, #T_569d9_row4_col6, #T_569d9_row4_col7, #T_569d9_row5_col0, #T_569d9_row5_col1, #T_569d9_row5_col2, #T_569d9_row5_col3, #T_569d9_row5_col4, #T_569d9_row5_col5, #T_569d9_row5_col6, #T_569d9_row5_col7 {
#   text-align: center;
#   border: 1px solid black;
# }
# </style>
# <table id="T_569d9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_569d9_level0_col0" class="col_heading level0 col0" >Timestamp</th>
#       <th id="T_569d9_level0_col1" class="col_heading level0 col1" >Open</th>
#       <th id="T_569d9_level0_col2" class="col_heading level0 col2" >High</th>
#       <th id="T_569d9_level0_col3" class="col_heading level0 col3" >Low</th>
#       <th id="T_569d9_level0_col4" class="col_heading level0 col4" >Close</th>
#       <th id="T_569d9_level0_col5" class="col_heading level0 col5" >Volume_(BTC)</th>
#       <th id="T_569d9_level0_col6" class="col_heading level0 col6" >Volume_(Currency)</th>
#       <th id="T_569d9_level0_col7" class="col_heading level0 col7" >Weighted_Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_569d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_569d9_row0_col0" class="data row0 col0" >1325317920</td>
#       <td id="T_569d9_row0_col1" class="data row0 col1" >4.390000</td>
#       <td id="T_569d9_row0_col2" class="data row0 col2" >4.390000</td>
#       <td id="T_569d9_row0_col3" class="data row0 col3" >4.390000</td>
#       <td id="T_569d9_row0_col4" class="data row0 col4" >4.390000</td>
#       <td id="T_569d9_row0_col5" class="data row0 col5" >0.455581</td>
#       <td id="T_569d9_row0_col6" class="data row0 col6" >2.000000</td>
#       <td id="T_569d9_row0_col7" class="data row0 col7" >4.390000</td>
#     </tr>
#     <tr>
#       <th id="T_569d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_569d9_row1_col0" class="data row1 col0" >1325317980</td>
#       <td id="T_569d9_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_569d9_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_569d9_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_569d9_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_569d9_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_569d9_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_569d9_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_569d9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_569d9_row2_col0" class="data row2 col0" >1325318040</td>
#       <td id="T_569d9_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_569d9_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_569d9_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_569d9_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_569d9_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_569d9_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_569d9_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_569d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_569d9_row3_col0" class="data row3 col0" >1325318100</td>
#       <td id="T_569d9_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_569d9_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_569d9_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_569d9_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_569d9_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_569d9_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_569d9_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_569d9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_569d9_row4_col0" class="data row4 col0" >1325318160</td>
#       <td id="T_569d9_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_569d9_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_569d9_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_569d9_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_569d9_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_569d9_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_569d9_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_569d9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_569d9_row5_col0" class="data row5 col0" >1325318220</td>
#       <td id="T_569d9_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_569d9_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_569d9_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_569d9_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_569d9_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_569d9_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_569d9_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (4857377, 8)

# %%
# Distribution of 'Open' and 'Close' prices over time
plt.figure(figsize=(12, 6))
plt.plot(df['Timestamp'], df['Open'], label='Open', color='blue')
plt.plot(df['Timestamp'], df['Close'], label='Close', color='red')
plt.xlabel('Timestamp')
plt.ylabel('Price')
plt.title('Open vs Close Prices Over Time')
plt.legend()
plt.show()

# %%
correlation_matrix = df.corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                    Timestamp      Open      High       Low     Close  \
# Timestamp           1.000000  0.650719  0.650644  0.650803  0.650714
# Open                0.650719  1.000000  0.999999  0.999999  0.999999
# High                0.650644  0.999999  1.000000  0.999998  0.999999
# Low                 0.650803  0.999999  0.999998  1.000000  0.999999
# Close               0.650714  0.999999  0.999999  0.999999  1.000000
# Volume_(BTC)       -0.103926 -0.051860 -0.051717 -0.052040 -0.051877
# Volume_(Currency)   0.228190  0.344074  0.344498  0.343541  0.344036
# Weighted_Price      0.650737  0.999999  0.999999  1.000000  1.000000
#
#                    Volume_(BTC)  Volume_(Currency)  Weighted_Price
# Timestamp             -0.103926           0.228190        0.650737
# Open                  -0.051860           0.344074        0.999999
# High                  -0.051717           0.344498        0.999999
# Low                   -0.052040           0.343541        1.000000
# Close                 -0.051877           0.344036        1.000000
# Volume_(BTC)           1.000000           0.352038       -0.051887
# Volume_(Currency)      0.352038           1.000000        0.344010
# Weighted_Price        -0.051887           0.344010        1.000000

# %%
# Volume (BTC) over time
plt.figure(figsize=(12, 6))
plt.plot(df['Timestamp'], df['Volume_(BTC)'], color='green')
plt.xlabel('Timestamp')
plt.ylabel('Volume (BTC)')
plt.title('Volume (BTC) Over Time')
plt.show()

# %%
df.dtypes.value_counts().plot.pie(autopct=('%0.2f%%'))
# Out:
# <Axes: ylabel='count'>

# %%
unique_values = df.nunique()
print("Unique Values:")
print(unique_values)
# Out:
# Unique Values:
# Timestamp            4857377
# Open                 1059732
# High                 1030826
# Low                  1046536
# Close                1058685
# Volume_(BTC)         3181865
# Volume_(Currency)    3562603
# Weighted_Price       3046022
# dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
missing_values = df.isnull().sum()
print("Missing Values:")
print(missing_values)
# Out:
# Missing Values:
# Timestamp                  0
# Open                 1243608
# High                 1243608
# Low                  1243608
# Close                1243608
# Volume_(BTC)         1243608
# Volume_(Currency)    1243608
# Weighted_Price       1243608
# dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Volume_(BTC)', y='Volume_(Currency)', data=df)
plt.xlabel("x-axis (BTC Volume)")
plt.ylabel("y-axis (Currency Volume)")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4857377 entries, 0 to 4857376
# Data columns (total 8 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Timestamp          int64
#  1   Open               float64
#  2   High               float64
#  3   Low                float64
#  4   Close              float64
#  5   Volume_(BTC)       float64
#  6   Volume_(Currency)  float64
#  7   Weighted_Price     float64
# dtypes: float64(7), int64(1)
# memory usage: 296.5 MB

# %%
df.hist(bins=20, legend=False, figsize=(20, 15))
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Low', y='High', data=df)
plt.xlabel("x-axis (Low Price)")
plt.ylabel("y-axis (High Price)")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.describe()
# Out:
#           Timestamp          Open          High           Low         Close  \
# count  4.857377e+06  3.613769e+06  3.613769e+06  3.613769e+06  3.613769e+06
# mean   1.471301e+09  6.009024e+03  6.013357e+03  6.004488e+03  6.009014e+03
# std    8.428019e+07  8.996247e+03  9.003521e+03  8.988778e+03  8.996360e+03
# min    1.325318e+09  3.800000e+00  3.800000e+00  1.500000e+00  1.500000e+00
# 25%    1.398179e+09  4.438600e+02  4.440000e+02  4.435200e+02  4.438600e+02
# 50%    1.471428e+09  3.596970e+03  3.598190e+03  3.595620e+03  3.597000e+03
# 75%    1.544288e+09  8.627270e+03  8.632980e+03  8.621090e+03  8.627160e+03
# max    1.617149e+09  6.176356e+04  6.178183e+04  6.167355e+04  6.178180e+04
#
#        Volume_(BTC)  Volume_(Currency)  Weighted_Price
# count  3.613769e+06       3.613769e+06    3.613769e+06
# mean   9.323249e+00       4.176284e+04    6.008935e+03
# std    3.054989e+01       1.518248e+05    8.995992e+03
# min    0.000000e+00       0.000000e+00    3.800000e+00
# 25%    4.097759e-01       4.521422e+02    4.438306e+02
# 50%    1.979811e+00       3.810124e+03    3.596804e+03
# 75%    7.278216e+00       2.569821e+04    8.627637e+03
# max    5.853852e+03       1.390067e+07    6.171621e+04

# %%
df = df.dropna()
df = df.drop_duplicates()
